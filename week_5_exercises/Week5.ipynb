# %% [markdown]
# # Week 5

# %% [markdown]
# ## Part 1: More lecturing on dataviz

# %% [markdown]
# ***Exercise 1.1***
#
# *Mention 10 examples of ways we can encode data*

# %% [markdown]
# ***Answer:***
# - *Like the sales of each month in a store (The bar chart)*
# - *Something like what ownership each person has of a certain stock (The pie chart)(Classically a bad way to represent it)*
# - *Mapping latitude/longtitude on a map (Geoencoding)*
# - *Time series plots of sales over time with months on the x-axis (Time series plots)*
# - *Time series plots of sales total sales (y-axis 1) and the amount of visitors to a webpage (y-axis 2) and months on the x-axis (Time series plots with several y-axes)*
# - *Density estimation for each point in a city (Like with the San Francisco crime incident reports, to estimate where most crimes are reported)*
# - *Make a correlation fit of sales over visitors to a webpage (Linear fit between two variables)*
# - *Links between components. Like A knows B, B knows C. What is the connection of A -> C (Network data)*
# - *A class hierarchy that shows the connection of Object Oriented Programming (Hierarchical data, dendrogram)*
# - *A tree that shows a family tree (Hierarchical data)*
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 1.2***
#
# *Are all encoding created equally? Why not?*

# %% [markdown]
# ***Answer:*** *No they are not, mainly because they are good/bad at representating different types of data. This could for instance be that you chose to use a Pearson Correlation for something that has a non-linear relationship*
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 1.3***
#
# *Explain in your own words: What is the problem with pie-charts?*

# %% [markdown]
# ***Answer:*** *Pie-charts are easy to misread - in general it is hard for our brain to distinguish something that is defined in angles. Therefore, two different values in a categorical datasets close to eachother might be indistinguishable in a pie-chart, whereas a bar chart would show this difference much clearer*
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 1.4***
#
# *Mention three encodings that are difficult for the human eye to parse? Can you find an example of a visualization online that uses one of those three?*

# %% [markdown]
# ***Answer:***
# - *Obviously as mentioned in the previous, a bar chart, [like this](http://livingqlikview.com/wp-content/uploads/2017/04/Worst-Data-Visualizations-07.jpg)*
# - *Another classic is the 3D bar chart, [like this](https://blog.hubspot.com/hs-fs/hubfs/Screen%20Shot%202020-09-02%20at%2011.23.44%20PM.png?width=1500&name=Screen%20Shot%202020-09-02%20at%2011.23.44%20PM.png)*
# - *One from my own field is [this](https://marvel-b1-cdn.bc0a.com/f00000000067087/www.bdcnetwork.com/sites/bdc/files/styles/content_display_image/public/abdullah12.jpg?itok=jCRezgL7). Often Computational Fluid Dynamics (CFD) is represented in nearly useless formats where my eye cannot conceive what is happening at all - but it looks pretty*
#
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 1.5***
#
# *What is a "Choropleth"? What does the ancient Greek root of that word "χώρος" mean?*

# %% [markdown]
# ***Answer:*** *'Found on wikipedia': choros means area or region, pleth means multitude. Which is exactly what it is. It shows a region of a map with a certain multitude of something - like how many electors a certain state contains in the USA*
# ______________________________________________________________________

# %% [markdown]
# ## Part 2: Exploratory data visualzation, two variables

# %% [markdown]
# ***Exercise 2.1***
#
# *Looking at Fig 3-1, Janert writes "the data itself shows clearly that the amount of random noise in the data is small". What do you think his argument is?*

# %% [markdown]
# ***Answer:*** *I would tend to agree since there are no obvious outliers in the dataset - an outlier disturbs the image that our brain is conceiving (A lot of outliers disturb it even more).*
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 2.2***
#
# *Can you think of a real-world example of a multivariate relationship like the one in Fig 3-3 (lower right panel)?*

# %% [markdown]
# ***Answer:*** *This might occur in many cases with health data. Let's for instance think of an example where we are looking at patients, and what age they had skin cancer diagnosed - obviously there will be more cases the older the patients get. But what about how much time they spend in the sun? This will probably mean that the age they had skin cancer was lower if they spent more time in the sun*
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 2.3***
#
# *What are the two methods Janert metions for smoothing noisy data? Can you think of other ones?*

# %% [markdown]
# ***Answer:***
# - *1. Weighted splines*
# - *2. LOESS*
# - *BONUS. Linear Regression*
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 2.4***
#
# *What is problematic about using straight lines to fit the data in Fig 3-5? (Something similar is actually the topic of a Nature article from 2004 get it here. And an extra link on this topic for the students who know Danish)*

# %% [markdown]
# ***Answer:*** *Fitting a straight line in the natural world would be quite difficult. If you simply fit a straight line on the data from fig 3-5, you will miss important aspects of the data, especially the fact that the winning times actually seem to be plateauing (flattening out) for the data points (Women around 145 minutes, and men around 130 minutes). A straight line would just violate the quadratic relationship, meaning that the speeds would increase to people running marathons in less than 1 second eventually.*
#
# *For instance in the nature article it assumes that the natural body will simply keep improving linearly. The problem with the article is that the "winning time" is a quadratic relationship, that might seem linear in a specific time frame. Hence, if you run 100 meters at 6 seconds, you would have to run ~60 km/h (constantly). If you want to improve that time to 3 seconds, you would have to run twice as fast (~120 km/h). This means that the closer you go to 0 seconds pr. 100 m, the higher your speed is. And it will increase infinetely, to beyond the speed of light, and even much higher*
#
# *Instead, what would happen would probably happen, is that the winning times would eventually converge towards a common result, where the body cannot be pushed further*
#
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 2.5***
#
# *What are residuals? Why is it a good idea to plot the residuals of your fit?*

# %% [markdown]
# ***Answer:***
#
# *The word 'residual' means 'the rest'. Like a residual of mining coal, would be residual waste.*
# *Specifically, in the world of statistics, the residual of a linear regression is the distance from the fitted line, to the actual observation. The larger the residual, the harder it is to represent the actual observation with the linear fit*
# *Therefore, plotting the residuals will give you an indication as to how well the fit goes with the dataset*
#
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 2.6***
#
# *Explain in your own words the point of the smooth tube in figure 3-7*

# %% [markdown]
# ***Answer:*** *The point is to examine whether the 'confidence band' changes on the curve. This might give us a clear indication that in some places, the data is more spread out in another. In fig 3-7 it introduces and shows that for the winning times in the 2000's are converging towards the same point (except from the large drop at the end of the curve)*
# ______________________________________________________________________

# %% [markdown]
# ***Exercise 2.7***
#
# *What kind of relationships will a semi-log plot help you discover?*

# %% [markdown]
# ***Answer:*** *It will help us explore exponential or power law behaviour. For some things plots this might not be possible to see before it has been plotted as a semi-log plot*
# _____________

# %% [markdown]
# ***Exercise 2.8***
#
# *What kind of functions will loglog plots help you see?*

# %% [markdown]
# ***Answer:*** *If there is a power law relation, loglog will help us plot that as a straight line instead. It will be quite useful for data where there is a large difference in x values - say that you have the carry capacity of a vehicle in people on the y-axis, and the weight of the vehicle in the x-axis. Since a ferry is extremely heavy, it will make all of the datapoints of cars, bicycles, scooters, mopads, airplanes etc. seem very small on the figure. By doing a loglog scale, these could be distributed equally over the figure*

# %% [markdown]
# ***Exercise 2.9***
#
# *What the h#ll is banking and what part of our visual system does it use to help us see patterns? What are potential problems with banking?*

# %% [markdown]
# ***Answer:*** *Banking is the technique of changing the aspect ratio of the plot visually, in order to as much as possible create an understandable representation of for instance very steep data. Whilst it can be useful in some cases, visually, it can also just dye out the details of the plot, making it impossible to see a specific point on the plot.*
# ___________________________

# %% [markdown]
# ***Exercise 2.10***
#
# *I think figure 3-14 makes an important point about linear fits that is rarely made. What is it?*

# %% [markdown]
# ***Answer:*** *The figure shows that maybe a linear regression is not as much the 'best fit' as the 'best predictor'. He goes on to explain how one would find the best fit, rather than predictor*
# ____________

# %% [markdown]
# ***Exercise 2.11***
#
# *Summarize the discussion of Graphical Analysis and Presentation Graphics on pp. 68-69 in your own words.*

# %% [markdown]
# ***Answer:*** *The author wants to create a clear definition of what `Graphical Analysis` is, compared to `Presentation Graphics`*
#
# *`Graphical Analysis` is the effect of analysing data, finding the right question to ask during the analysis of the data*
#
# *`Presentation Graphics` varies by being a presentation of things already discovered in the data analysis. It is about clearly and consicely comminucating your result to an outsider*
#
# The author then goes on to say, that during `Graphical Analysis` you have an open graph, meaning: Don't polish the graph in any way. You are exploring the data, and you are taking a look at the data from ALL angles. For instance, don't point out things graphically in the plots, as it would take you too long to go through the data.
#
# Furthermore, he explains that during the `Presentation Graphics` the opposite should apply, and he even goes on to list:*
#
# - *Text should be self-explanatory*
# - *Explain what is plotted on the axes*
# - *Make labels self explanatory*
# - *Use a suitable font for your graphics (Don't use an annoying font, that doesn't correspond to everywhere else in your presentation)*
# - *Explain error bars on the plot*
# - *Choose appropriate ranges for the representation of data on the graph*
# - *Always proofread all graphs.*
# - *Chose appropriate output formats, like PDF or PostScript*
#
# ______

# %% [markdown]
# ## Part 3: Logarighmic plots

# %% [markdown]
# ***Exercise 3.1***
#
# *First, we'll simply create a version of this plot from Lecture 1, where you display the $y$-axis on log-scale.*

# %% [markdown]
# ***Answer:***

# %% [markdown]
# *We start by importing the needed packages for the data analysis*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
policing_dataframe = pd.read_csv('../rawdata/Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv', parse_dates=[['Date', 'Time']])

# %% [markdown]
# *We now try to plot the data with a logarithmic y-axis*

# %%
counts_pr_category = policing_dataframe.groupby(by=["Category"]).size().reset_index(name="Incidents reported")

# %% [markdown]
# *We sort the values to make it more comprehensible*

# %%
counts_pr_category_sorted = counts_pr_category.sort_values("Incidents reported", ascending=False).reset_index(drop=True)

# %% [markdown]
# *We start off by recreating the original plot*

# %%
counts_pr_category_sorted.plot(x='Category', y='Incidents reported', kind='bar', figsize=(15,8), log=False, color="black")
plt.title("With non-log y-axis", pad=-14)
plt.show()

# %% [markdown]
# *Now we can create the plot asked for in the assignment, with the y-axis as a log-scale*

# %%
counts_pr_category_sorted.plot(x='Category', y='Incidents reported', kind='bar', figsize=(15,8), log=True, color="black")
plt.title("With non-log y-axis", pad=-14)
plt.show()

# %% [markdown]
# ____________________________

# %% [markdown]
# ***Exercise 3.2***
#
# *Let's also try a loglog plot. Inspired by this article I would expect that especially theft could be characterized by a power law distribution also in san francisco. Let's see if I'm right.*
#
# ***We assume that with theft is meant `LARCENY/THEFT` only***

# %% [markdown]
# - ***Step 1:*** *Divide San Francisco into a grid roughly $100m \times 100m$. You can, for example use numpy to do this, I would call np.histogram2d, and searching the internet, it seems that there are also ways to do this in pandas. The earth isn't flat,so lat lon aren't really squares, but if setting up a true grid of distances seems like too much work, it's OK to just use fractions of lat/lon as bin-edges even though those aren't completely square.*

# %% [markdown]
# *We start of by converting the lat/lon to a 2d plane, with the use of above suggested code*

# %% [markdown]
# *We create a function that can convert meters into equivalent degrees of the earth [link](https://www.usna.edu/Users/oceano/pguth/md_help/html/approx_equivalents.htm)*

# %%
def meters_to_degrees(meters):
    degrees_0_0001_in_meters = 11.1
    return round((meters / degrees_0_0001_in_meters) * 0.0001, 9)

# %% [markdown]
# *Now we use the function in the above suggested text that projects our globe to a flat plane [link](https://stackoverflow.com/questions/39254704/pandas-group-bins-of-data-per-longitude-latitude)*

# %%
size_of_grid = 100
degrees = meters_to_degrees(size_of_grid)
to_bin = lambda x: np.floor(x / degrees) * degrees
policing_dataframe["latbin"] = policing_dataframe.X.map(to_bin)
policing_dataframe["lonbin"] = policing_dataframe.Y.map(to_bin)

# %% [markdown]
# - ***Step 2:*** *Count the number of thefts occurring within each grid-square (use all data for all time).*

# %%
mask = (policing_dataframe['Category'] == "LARCENY/THEFT")
df_thefts_in_each_part_of_grid = policing_dataframe.loc[mask].reset_index(drop=True)

thefts_in_each_part_of_grid = policing_dataframe.groupby(by=["latbin", "lonbin"]).size().reset_index(drop=True)

# %% [markdown]
# - ***Step 3:*** *Tally the counts. Count the number of squares with $k=0$ thefts. We call this $N(0)$. Next, count the number of grids with one crime to get $N(k=1)$. Keep going like this all the way up to $k=C_{max}$, where $C_{max}$ is the highest count of crimes you find in any grid space.*

# %% [markdown]
# *We create a for loop that loops through where i amount of crimes have happened and adds it to the list, to later get the length of the list*

# %%
thefts = []
number_of_grids_with_theft_count = []
for i in range(np.max(thefts_in_each_part_of_grid)):
    thefts.append(i)
    number_of_grids_with_theft_count.append(len(np.where(thefts_in_each_part_of_grid == i)[0]))

# %% [markdown]
# *We now send the count to a dataframe and create an x-axis to plot on*

# %%
df_count = pd.DataFrame(number_of_grids_with_theft_count, columns=["squares with x crimes"]).reset_index().rename(columns={"index": "x"})

# %% [markdown]
# - ***Step 4:*** *Plot the distribution of $k+1$ vs $N(k)$ on linear axes.*

# %%
plt.bar(x=df_count["x"], height=df_count["squares with x crimes"])
plt.show()

# %% [markdown]
# - ***Step 5:*** *Plot the distribution of $k+1$ vs $N(k)$ on loglog axes.*

# %%
plt.bar(x=df_count["x"], height=df_count["squares with x crimes"], log=True, width=0.4)
plt.xscale("log")
plt.show()

# %% [markdown]
# ***Step 6:*** *Was Sune correct in assuming that there is a power-law distribution of theft*

# %% [markdown]
# ***Answer:*** No, since the points don't fall on a straight line, it seems that there is no power-law distribution*
# ___________

# %% [markdown]
# ## Part 4: Linear regression

# %% [markdown]
# ***Exercise 4.1***
# ***Create the 91 scatterplots***
#
# - *Make sure to label each one with the two crime-types you're comparing so we can easily inspect visually.*
# - *Make sure that that you squeeze the subplots closely together so each plot can be as big as possible.*
# - *Just inspecting this matrix, which crime-types look correlated and which one look like they're very different?*

# %%
focuscrimes = ['WEAPON LAWS', 'PROSTITUTION', 'DRIVING UNDER THE INFLUENCE', 'ROBBERY', 'BURGLARY', 'ASSAULT', 'DRUNKENNESS', 'DRUG/NARCOTIC', 'TRESPASS', 'LARCENY/THEFT', 'VANDALISM', 'VEHICLE THEFT', 'STOLEN PROPERTY', 'DISORDERLY CONDUCT']

# %% [markdown]
# *We add the hour of the week to the dataframe*

# %%
policing_dataframe["HourOfWeek"] = policing_dataframe["Date_Time"].dt.dayofweek * 24 + policing_dataframe["Date_Time"].dt.hour

counts_pr_category_pr_hour_pr_week = policing_dataframe.groupby(by=["HourOfWeek", "Category"]).size().reset_index(name="counts")
counts_pr_category_pr_hour_pr_week = counts_pr_category_pr_hour_pr_week.loc[counts_pr_category_pr_hour_pr_week['Category'].isin(focuscrimes)].reset_index(drop=True)

# %% [markdown]
# *We create a function that takes two crime types and generates the x and y values for the scatterplot*

# %%
def scatter_plot_crime_type(crime_type_1, crime_type_2, ite):
    crime_1_x = counts_pr_category_pr_hour_pr_week.loc[counts_pr_category_pr_hour_pr_week["Category"] == crime_type_1].reset_index(drop=True)["counts"]
    crime_2_y = counts_pr_category_pr_hour_pr_week.loc[counts_pr_category_pr_hour_pr_week["Category"] == crime_type_2].reset_index(drop=True)["counts"]
    
    ax[ite].scatter(x=crime_1_x, y=crime_2_y)
    ax[ite].set_title(crime_type_1+"\n"+crime_type_2, pad=-14, fontsize=7)
    ax[ite].set_xticks([])
    ax[ite].set_yticks([])
    

### For code simplicity we add this function to determine whether two variables have been plotted before
def not_analysed(crimes_correlated, crime_type_1, crime_type_2):
    if crime_type_1 != crime_type_2 and [crime_type_1, crime_type_2] not in crimes_correlated and [crime_type_2, crime_type_1] not in crimes_correlated:
        return True
    else:
        return False

# %% [markdown]
# *We can now loop through our crimetypes to see if they are correlated. We then call our plotting function*

# %%
fig, ax = plt.subplots(13, 7, figsize=(15,30))
ax = ax.ravel()

crimes_correlated = []
iteration = 0

for i in range(len(focuscrimes)):
    
    for j in range(len(focuscrimes)):
        is_not_analysed = not_analysed(crimes_correlated, focuscrimes[i], focuscrimes[j])
        
        if is_not_analysed:
            crimes_correlated.append([focuscrimes[i], focuscrimes[j]])
            scatter_plot_crime_type(focuscrimes[i], focuscrimes[j], iteration)
            iteration += 1

# %% [markdown]
# ***Question:*** *Just inspecting this matrix, which crime-types look correlated and which one look like they're very different?*

# %% [markdown]
# ***Answer:***
#
# ***`WEAPON LAWS`:***
# - *Shows a strong positive linear correlation with `ASSAULT`*
# - *Shows a mild positive linear correlation with `LARCENY/THEFT`, `VANDALISM`, `VEHICLE THEFT`, `STOLEN PROPERTY`*
# - *Other than that, no obvious linear correlation*
#
# ***`PROSTITUTION`:***
# - *Does not show any obvious linear correlation*
#
# ***`DRIVING UNDER THE INFLUENCE`:***
# - *Shows a strong positive correlation with `DRUNKENNESS`*
# - *Other than that, no obvious linear correlation*
#
# ***`ROBBERY`***
# - *Shows a mild-strong positive linear correlation with `ASSAULT` and `DRUNKENNESS`*
# - *Other than that, no obvious linear correlation*
#
# ***`BURGLARY`***
# - *Shows a mild positive linear correlation with `LARCENY/THEFT`*
#
# ***`ASSAULT`***
# - *Shows a strong positive linear correlation with `DRUNKENNESS`, `LARCENY/THEFT`, and `VANDALISM`*
# - *Shows a mild positive linear correlation with `VEHICLE THEFT` and `STOLEN PROPERTY`*
# - *Other than that, no obvious linear correlation*
#
# ***`DRUNKENNESS`***
# - *Shows a mild positive linear correlation with `VANDALISM`*
# - *Other than that, no obvious linear correlation*
#
# ***`DRUG/NARCOTIC`***
# - *Shows a strong linear correlation with `STOLEN PROPERTY`*
# - *Other than that, no obvious linear correlation*
#
# ***`TRESPASS`***
# - *Shows a mild positive linear correlation with `DISORDERLY CONDUCT`*
# - *Other than that, no obvious linear correlation*
#
# ***`LARCENY/THEFT`***
# - *Shows a strong linear correlation with `VANDALISM` and `VEHICLE THEFT`*
# - *Shows a mild linear correlation with `STOLEN PROPERTY`*
# - *Other than that, no obvious linear correlation*
#
# ***`VANDLISM`***
# - *Shows a strong linear correlation with `VEHICLE THEFT`*
# - *Other than that, no obvious linear correlation*
#
# ***`VEHICLE THEFT`***
# - *Shows no obvious linear correlation*
#
# ***`STOLEN PROPERTY`***
# - *Shows no obvious linear correlation*
# ______

# %% [markdown]
# ***Exercise 4.2***

# %% [markdown]
# *Using the formulas we derived above (Equation 1 and 2), to calculate slopes for $a$ and $b$ in each case, and add a linear fit to each of the 91 scatterplots. (If you'd like, you can use a built package/function for fitting straight lines to check that everything is working as expected.)*

# %% [markdown]
# *We start by calculating the slope of the fit with sklearn to be able to compare*

# %%
from scipy.stats import linregress
import seaborn as sns

# %%
def scatter_plot_crime_type_linreg(crime_type_1, crime_type_2, ite):
    
    crime_1_x = counts_pr_category_pr_hour_pr_week.loc[counts_pr_category_pr_hour_pr_week["Category"] == crime_type_1].reset_index(drop=True)["counts"]
    crime_2_y = counts_pr_category_pr_hour_pr_week.loc[counts_pr_category_pr_hour_pr_week["Category"] == crime_type_2].reset_index(drop=True)["counts"]
    slope, intercept, r_value, p_value, std_err = linregress(crime_1_x,crime_2_y)
    
    ax[ite].plot(crime_1_x, slope*crime_1_x+intercept, color="red")
    ax[ite].scatter(x=crime_1_x, y=crime_2_y)
    ax[ite].set_title(crime_type_1+"\n"+crime_type_2, pad=-14, fontsize=7)
    ax[ite].set_xticks([])
    ax[ite].set_yticks([])

# %%
fig, ax = plt.subplots(13, 7, figsize=(15,30))
ax = ax.ravel()

crimes_correlated = []
iteration = 0

for i in range(len(focuscrimes)):
    
    for j in range(len(focuscrimes)):
        is_not_analysed = not_analysed(crimes_correlated, focuscrimes[i], focuscrimes[j])
        
        if is_not_analysed:
            crimes_correlated.append([focuscrimes[i], focuscrimes[j]])
            scatter_plot_crime_type_linreg(focuscrimes[i], focuscrimes[j], iteration)
            iteration += 1
