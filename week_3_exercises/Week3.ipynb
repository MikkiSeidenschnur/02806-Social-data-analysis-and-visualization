# %% [markdown]
# # Week 3
#
# I hope you're getting the hang of things. Today we're introducing a new element, namely lectures by me on the prinicples of data visualization.
#
# *It's important for me to highlight that these lectures are quite important. We don't have a formal book on data visualization. So the only source of knowledge about the **principles**, **theories**, and **ideas**, that are the foundation for good data viz, comes from those videos*. So watch them 🤓
#
# I ramble on about that a bit more in the informal intro
#
# ## Informal intro

# %%
# short video explaining the plans
from IPython.display import YouTubeVideo
YouTubeVideo("KOuIqyVe6b8",width=600, height=333)

# %% [markdown]
# ## Overview
#
# Once again, the lecture has three parts
#
# * First you will watch some videos on visualization. There are 2 videos, one with a general overview, then we get more specifc.
# * After that, we'll be reading about *scientific data visualization*, and the huge number of things you can do with just one variable. Naturally, we'll be answering questions about that book.
# * And finally reproducing some of those the plots from that book.

# %% [markdown]
# ## Part 1: Fundamentals of data visualization
#
# Find your headphones and get an intro to data visualization.

# %%
# Intro video
from IPython.display import YouTubeVideo
YouTubeVideo("9D2aI30AMhM",width=800,height=450)

# %% [markdown]
# > *Excercise:* Questions for the lecture
# > * What is the difference between *data* and *metadata*? How does that relate to the bike-example?
# > * Sune says that the human eye is a great tool for data analysis. Do you agree? Explain why/why not. Mention something that the human eye is very good at. Can you think of something that [is difficult for the human eye](http://cdn.ebaumsworld.com/mediaFiles/picture/718392/84732652.jpg). Explain why your example is difficult.
# > * Simpson's paradox is hard to explain. Come up with your own example - or find one on line.
# > * In your own words, explain the differnece between *exploratory* and *explanatory* data analysis.
#
#
# Next, something a bit more specific on data analysis. Digging a bit more into the theory.

# %% [markdown]
# ***Difference between data and metadata***
#
# *The main difference is that data describes a phenomenon, like physical measurements of weather data, whilst meta data gives context to data, like describing at which weather station the data was measured.*
#
# ***What is the human eye good at***
#
# *Whilst the human eye is good for LOOKING at data, you still need to bring your brain to understand it. The eye can make sense of data that is structured in a way that we can bring our head (brain) around the data.*
#
# ***What is the human eye bad at***
#
# *Lifting heavy objects... Just a joke. Our eyes and brain have a tendency to procedurally process data, looking to recognize patterns that makes the previous data make sense - this means that if we do not perceive a pattern, then we cannot comprehend the data. This could for instance be a large feature set for machine learning that has 750 columns - we don't see the connection of this before the data has been structured in a manner that our brains can look for a pattern. Furthermore, our brains hunger to generate and see patterns create a massive bias in data - it gives us a tendency to stop looking for patterns the second we already found one pattern - this pattern might be accidental, but our brain has already released endorphines in our bloodstream, satisfying our OCD to find patterns (OK, OK, that's a long explanation that is more my personal experience than explained science)*
#
# ***What is the Simpson's paradox, give an example***
#
# *From my understanding, the simpson's paradox is that the statistical trends for the aggregated data is different from the trends of the subdivided data. This is for instance shown in this [youtube video](https://www.youtube.com/watch?v=t-Ci3FosqZs). When you aggregate data, then you can take for instance 3 seperated datasets that shown and upward trendline seperatedly, but when you aggregate them, the trendline might show as downward, because the 3 data sets are placed differently, but shows the same trend*
#
# ***Explain the difference between exploratory and explanatory data analysis***
#
# *To do an exploratorive data analysis is to get familiar with the data - to understand whether the data seems to have any apparent trends. It's like shaking bushes in the wild, hoping that some food will come out of it*
# *To do an explanatory data analysis is to take that food that came out and tell everyone in the camp why the food came out of exactly that bush, and not the previous one. Hopefully this will help people understand which bushes they should shake next time then want a steak!*

# %%
YouTubeVideo("yiU56codNlI",width=800, height=450)

# %% [markdown]
# > *Excercise:* Questions for the lecture
# > * As mentioned earlier, visualization is not the only way to test for correlation. We can (for example) calculate the Pearson correlation. Explain in your own words how the Pearson correlation works and write down it's mathematical formulation. Can you think of an example where it fails (and visualization works)?
# > * What is the difference between a bar-chart and a histogram?
# > * I mention in the video that it's important to choose the right bin-size in histograms. But how do you do that? Do a Google search to find a criterion you like and explain it.

# %% [markdown]
# ***What is the Pearson Correlation, and where does it fail***
#
# *The pearson correlation is a way to look for linear relations in datasets, described by the formula:*
#
# &emsp;
# $$r_{pearson} = \displaystyle \frac{n(\sum xy) - \sum x \sum y}{\sqrt{(n\sum x^2 - (\sum x)^2) \times (n\sum y^2) - (\sum y)^2)}    }$$
# &emsp;&emsp;
#
# *In general the pearson correlation handles some things poorly: like non-linear relationships - which occurs all the time in the natural world.*
# *Furthermore, the pearson correlation has a tendency to be greatly affected by outliers - they can both create a correlation that isn't there, or deduct that there is no correlation because of one point that is marginally different from the sample*
#
# ***What is the difference between a bar-chart and a histogram***
#
# *1. Histograms are used to show the distribution of variables whereas bar charts compare several variables*
#
# *2. Histograms bins data while bar charts are categorical*
#
# ***How do you chose the right bin-size for a histogram***
#
# *There are a few ways (Quantative & Qualitative) to do it. One method we thought sounds cool is the Sturge's Rule (It has been critized for over smoothing histograms). It's more a rule of thumb than a perfect formula:*
#
# &emsp;
# $$K = 1 + 3.322 log_{n}$$
# &emsp;&emsp;
#
# *Supposedly it works best for continous data which is normally distributed and symmetrical* ([source](https://www.statisticshowto.com/choose-bin-sizes-statistics/))

# %% [markdown]
# ## Part 2: Reading about the theory of visualization
#
# Since we can go deeper with the visualization this year, we are going to read the first couple of chapters from [*Data Analysis with Open Source Tools*](http://shop.oreilly.com/product/9780596802363.do). It's pretty old, but I think it's a fantastic ressource and one that is pretty much as relevant now as it was back then. The author is a physicist (like me) so I like the way he thinks. And the books takes the reader all the way from visualization, through modeling to computational mining. Anywho - it's a great book and well worth reading in its entirety.
#
# As part of this class we'll be reading the first chapters. Today, we'll read chaper 2 (28 pages) which supports and deepens many of the points I made during the first lecture (second video above).
#
# To find the text, you will need to go to **DTU Learn**. It's under "Course content" $\rightarrow$ "Lecture 3 reading".

# %% [markdown]
# > *Excercise*: Questions for DAOST
# > * Explain in your own words the point of the jitter plot.
# > * Explain in your own words the point of figure 2-3. (I'm going to skip saying "in your own words" going forward, but I hope you get the point; I expect all answers to be in your own words).
# > * The author of DAOST (Philipp Janert) likes KDEs (and think they're better than histograms). And I don't. I didn't give a detailed explanation in the video, but now that works to my advantage. I'll ask you guys to think about this and thereby create an excellent exercise: When can KDEs be misleading? (I'll provide the answer in a later lecture :)
# > * I've discussed some strengths of the CDF - there are also weaknesses. Janert writes "CDFs have less intuitive appeal than histograms of KDEs". What does he mean by that?
# > * What is a *Quantile plot*? What is it good for.
# > * How is a *Probablity plot* defined? What is it useful for? Have you ever seen one before?
# > * One of the reasons I like DAOST is that Janert is so suspicious of mean, median, and related summary statistics. Explain why one has to be careful when using those - and why visualization of the full data is always better.
# > * I love box plots. When are box plots most useful?
# > * The book doesn't mention [violin plots](https://en.wikipedia.org/wiki/Violin_plot). Are those better or worse than box plots? Why?

# %% [markdown]
# ***Explain what the point is of a jitter plot***
#
# *The jitter plot assigns a random value on data that is clustered directly on top of each other. This makes it possible to distinguish several data points clustered on top of eachother. It should not be used, for instance for geographical data*
#
# *Plainly, it means that chosing the bin sizes of a histogram can greatly affect what the data looks like. From figure 2 i might assume that the data is distributed evenly, and from figure 3 it's obvious that it's not*
#
# ***When are KDE's misleading***
#
# *They may deceive you, since the bandwidth of the KDE is extremely important. If you set the bandwidth too narrow or wide, it may represent your data incorrectly. Also, the KDE plot may seem convincing due to its smooting of the plot*
#
# ***What does it mean that "CDFs have less intuitive appeal than histograms of KDEs"?***
#
# *Histograms and KDEs have a tendency to look right from the get-go, whereas cumulative curves can seem less intuitive. This is because they simply take the overall data and sum the total data up. This means that it shows the occurence of datapoints in the total count. I've personally always loved cumulative curves, as they give us a good idea of HOW MUCH of the data is located in a specific part of the dataset*
#
# ***What is a quantile plot and what is it good for***
#
# *An example: You have a room indoors. In this room, you want it to be below 26C degrees, for more than 95% of the year (These are the rules for the danish building regulation). This can be evaluated by doing a quantile plot with the temperature measurements over a year, on the y-axis and the percentage on the x-axis. This way we can make sure that this requirement is held, so that people don't fall over from heat exhaustion (Or we spent too much energy on cooling the room) - Therefore I like it for time based data (Or something like spacial data, like square meters)*
#
# ***How is a probability plot defined***
#
# *A probability is a graphical way to determine whether or not a data set follows a given distribution. The closer it is to a straight line, the more likely it is to follow that distribution*
#
# ***Why should you be careful with using mean, median and general summary statistics***
#
# *As discussed in the previous weekly assignement, statistics can be the same for different datasets, even though the datasets are not the same. For instance the mean value is greatly affected by outliers, which ultimately can result in misrepresenting a dataset, by saying something like: "The mean life expectancy is 84 years". This is misrepresented if that happened because 20 people died at age 180, and 100 people died at age 65*
#
# ***When are box plots most useful***
#
# *It is quite useful during explanatory analysis. It can give a good idea on the distribution of the data and whether the median of the data is placed with a positive, negative, or no skewness*
#
# ***Are violin plots better/worse than box plots?***
#
# *Violin plots show the multimodal nature of a dataset, whereas box plots do not. That is also why they are called violin-plots - the multimodal..ness of the data set will make it look like a violin*

# %% [markdown]
# ## Part 3: *Finally*! Let's create some visualizations

# %% [markdown]
# > *Excercise*: Connecting the dots and recreating plots from DAOST but using our own favorite dataset.
# > * Let's make a jitter-plot (that is, code up something like **Figure 2-1** from DAOST from scratch), but based on SF Police data. My hunch from inspecting the file is that the police-folks might be a little bit lazy in noting down the **exact** time down to the second. So choose a crime-type and a suitable time interval (somewhere between a month and 6 months depending on the crime-type) and create a jitter plot of the arrest times during a single hour (like 13-14, for example). So let time run on the $x$-axis and create vertical jitter.
# > * Last time, we did lots bar-plots. Today, we'll play around with histograms (creating two crime-data based versions of the plot-type shown in DAOST **Figure 2-2**). I think the GPS data could be fun to see this way.
# >   * This time, pick two crime-types with different geographical patterns **and** a suitable time-interval for each (you want between 1000 and 10000 points in your histogram)
# >   * Then take the latitude part of the GPS coordinates for each crime and bin the latitudes so that you have around 50 bins across the city of SF. You can use your favorite method for binning. I like `numpy.histogram`. This function gives you the counts and then you do your own plotting.
# > * Next up is using the plot-type shown in **Figure 2-4** from DAOST, but with the data you used to create Figure 2.1. To create the kernel density plot, you can either use `gaussian_kde` from `scipy.stats` ([for an example, check out this stackoverflow post](https://stackoverflow.com/questions/4150171/how-to-create-a-density-plot-in-matplotlib)) or you can use [`seaborn.kdeplot`](https://seaborn.pydata.org/generated/seaborn.kdeplot.html).
# > * Now grab 25 random timepoints from the dataset (of 1000-10000 original data) you've just plotted and create a version of Figure 2-4 based on the 25 data points. Does this shed light on why I think KDEs can bee misleading?
# >
# > Let's take a break. Get some coffee or water. Stretch your legs. Talk to your friends for a bit. Breathe. Get relaxed so you're ready for the second part of the exercise. Ok. Now for more plots :)
# >
# > * Now we'll work on creating two versions of the plot in **Figure 2-11**, but using the GPS data you used for your version of Figure 2-2. Comment on the result. It is not easy to create this plot from scracth, Hint: Take a look at the `scipy.stats.probplot` function.
# > * OK, we're almost done, but we need some box plots. Here, I'd like you to use the box plots to visualize fluctuations of how many crimes happen per day. We'll use data from the 15 focus crimes defined last week.
# >   * For the full time-span of the data, calulate the **number of crimes per day** within each category for the entire duration of the data.
# >   * Create a box-and whiskers plot showing the mean, median, quantiles, etc for all 15 crime-types side-by-side. There are many ways to do this. I like to use [matplotlibs's built in functionality](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.boxplot.html)
# >   * What does this plot reveal that you can't see in the plots from last time?
# > * Also I want to show you guys another interesting use of box plots. To get started, let's calculate another average for each focus-crime, namely what time of day the crime happens. So this time, the distribution we want to plot is the average time-of-day that a crime takes place. There are many ways to do this, but let me describe one way to do it.
#     * For datapoint, the only thing you care about is the time-of-day, so discard everything else.
#     * You also have to deal with the fact that time is annoyingly not divided into nice units that go to 100 like many other numbers. I can think of two ways to deal with this.
#       * For each time-of-day, simply encode it as seconds since midnight.
#       * Or keep each whole hour, and convert the minute/second count to a percentage of an hour. So 10:15 $\rightarrow$ 10.25, 8:40 $\rightarrow$ 8.67, etc.
#     * Now you can create box-plots to create an overview of *when various crimes occur*. Note that these plot have quite a different interpretation than ones we created in the previous exercise. Cool, right?

# %% [markdown]
# ***Let's create our own jitter plot, with the time noted pr. crime over a month on the x-axis. We chose to look more specifically into `Assualt`s***

# %% [markdown]
# *We import the necessary packages*

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# *We import the policing dataframe, and parse the date and time as a datetime*

# %%
policing_dataframe = pd.read_csv('../files/Police_Department_Incident_Reports__Historical_2003_to_May_2018.csv', parse_dates=[['Date', 'Time']])

# %% [markdown]
# *We assign a mask to select all the data in February 2013*

# %%
mask = (policing_dataframe['Date_Time'] > "2013-02-01") & (policing_dataframe['Date_Time'] <= "2013-06-28")
df_assaults = policing_dataframe.loc[mask].reset_index(drop=True)

# %% [markdown]
# *We specifically select the crimes of category == ASSAULT*

# %%
df_assaults = df_assaults.loc[df_assaults['Category'] == "ASSAULT"].reset_index(drop=True)

# %% [markdown]
# *We filter the data to stuff that happened from 21:00 - 22:00*

# %% [markdown]
# *We create a time interval and add it to the df_assaults dataframe*

# %%
hours_in_day = [i for i in range(0,24)]
hourly_slots = {}
for i in range(len(hours_in_day)):
    if i+1 == len(hours_in_day):
        from_time = hours_in_day[i]
        to_time = hours_in_day[0]
        hourly_slots[from_time] = str(from_time) + "-" + str(to_time)
    else:
        from_time = hours_in_day[i]
        to_time = hours_in_day[i+1]
        hourly_slots[from_time] = str(from_time) + "-" + str(to_time)
    
print(hourly_slots)
# Out:
# {0: '0-1', 1: '1-2', 2: '2-3', 3: '3-4', 4: '4-5', 5: '5-6', 6: '6-7', 7: '7-8', 8: '8-9', 9: '9-10', 10: '10-11', 11: '11-12', 12: '12-13', 13: '13-14', 14: '14-15', 15: '15-16', 16: '16-17', 17: '17-18', 18: '18-19', 19: '19-20', 20: '20-21', 21: '21-22', 22: '22-23', 23: '23-0'}

# %%
df_assaults["time_period"] = [hourly_slots[int(str(i).split(":")[0])] for i in list(df_assaults['Date_Time'].dt.hour)]

# %%
df_assaults_filtered = df_assaults.loc[df_assaults['time_period'] == "21-22"].reset_index(drop=True)

# %% [markdown]
# *We create a scatterplot with jitter*

# %%
x = df_assaults_filtered["Date_Time"].dt.minute

# %%
plt.figure(figsize=(10,10))
ax = sns.stripplot(x=x, jitter=True)

# %% [markdown]
# *From the above plot it is obvious that the police have a tendency to round up to the nearest 10 minutes. Or crimes just happen like that - which seems hard to believe ;)*

# %% [markdown]
# ***We now want to create histograms that show two different crime types with different geographical patterns***

# %% [markdown]
# *We have chosen `VEHICLE THEFT` & `PROSTITUTION` as they seem to show different geographical patterns*
#
# *We want between 1000 and 10000 counts of each type*

# %%
mask_time_veh = (policing_dataframe['Date_Time'] > "2013-02-01") & (policing_dataframe['Date_Time'] <= "2014-02-28")
mask_time_pro = (policing_dataframe['Date_Time'] > "2013-02-01") & (policing_dataframe['Date_Time'] <= "2017-06-28")

df_vehicle_theft = policing_dataframe.loc[mask_time_veh].reset_index(drop=True)
df_prostitution = policing_dataframe.loc[mask_time_pro].reset_index(drop=True)

# %%
df_vehicle_theft = df_vehicle_theft.loc[df_vehicle_theft['Category'] == "VEHICLE THEFT"].reset_index(drop=True)
df_prostitution = df_prostitution.loc[df_prostitution['Category'] == "PROSTITUTION"].reset_index(drop=True)

# %%
pro_count = df_prostitution["Date_Time"].count()
veh_count = df_vehicle_theft["Date_Time"].count()

print("Count of vehicle theft: {}".format(veh_count))
print("Count of prostition charges: {}".format(pro_count))
# Out:
# Count of vehicle theft: 6659
# Count of prostition charges: 2334

# %% [markdown]
# *We have now have the two dataframes that we want to make histograms. We will now create bins of the latitude of these crimes*

# %%
x_pro = df_prostitution["X"]
x_veh = df_vehicle_theft["X"]

# %%
plt.figure(figsize=(10,10))
sns.distplot(x_pro, kde=False, bins=50, hist_kws=dict(edgecolor="k", linewidth=1)).set_title("Histogram of prostitution by latitude")
# Out:
# Text(0.5, 1.0, 'Histogram of prostitution by latitude')

# %%
plt.figure(figsize=(10,10))
sns.distplot(x_veh, kde=False, bins=50, hist_kws=dict(edgecolor="k", linewidth=1)).set_title("Histogram of prostitution by latitude")
# Out:
# Text(0.5, 1.0, 'Histogram of vehicle thefts by latitude')

# %% [markdown]
# ***Now we want to create a kernel-density plot based of the above histograms***

# %% [markdown]
# *We will be using the seaborn package for that. We will plot all of the KDE's with bandwidth=`[0.02, 0.01, 0.005, 0.001]` to investigate the difference*

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,15), sharey=True, sharex=True)

sns.distplot(ax = axes[0,0], a=x_pro, kde=True, bins=50, kde_kws=dict(bw=0.02, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
axes[0,0].set_title("Histogram of prostitution by latitude, bw=0.02")

sns.distplot(ax = axes[0,1], a=x_pro, kde=True, bins=50, kde_kws=dict(bw=0.01, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
axes[0,1].set_title("Histogram of prostitution by latitude, bw=0.01")

sns.distplot(ax = axes[1,0], a=x_pro, kde=True, bins=50, kde_kws=dict(bw=0.005, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
axes[1,0].set_title("Histogram of prostitution by latitude, bw=0.005")

sns.distplot(ax = axes[1,1], a=x_pro, kde=True, bins=50, kde_kws=dict(bw=0.001, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
axes[1,1].set_title("Histogram of prostitution by latitude, bw=0.001")
# Out:
# Text(0.5, 1.0, 'Histogram of prostitution by latitude, bw=0.001')

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,15), sharey=True, sharex=True)

sns.distplot(ax = axes[0,0], a=x_veh, kde=True, bins=50, kde_kws=dict(bw=0.02, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
axes[0,0].set_title("Histogram of vehicle theft by latitude, bw=0.02")

sns.distplot(ax = axes[0,1], a=x_veh, kde=True, bins=50, kde_kws=dict(bw=0.01, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
axes[0,1].set_title("Histogram of vehicle theft by latitude, bw=0.01")

sns.distplot(ax = axes[1,0], a=x_veh, kde=True, bins=50, kde_kws=dict(bw=0.005, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
axes[1,0].set_title("Histogram of vehicle theft by latitude, bw=0.005")

sns.distplot(ax = axes[1,1], a=x_veh, kde=True, bins=50, kde_kws=dict(bw=0.001, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
axes[1,1].set_title("Histogram of vehicle theft by latitude, bw=0.001")
# Out:
# Text(0.5, 1.0, 'Histogram of vehicle theft by latitude, bw=0.001')

# %% [markdown]
# *As seen above, the KDE bandwidth greatly influence the KDE shape. For instance it seems that the bandwidth of 0.02 is generally too high, and it over-smoothes the KDE curve*

# %%
df_vehicle_theft_sample = df_vehicle_theft.sample(n=25)
df_prostitution_sample = df_prostitution.sample(n=25)

# %%
sample_veh_x = df_vehicle_theft_sample["X"]
sample_pro_x = df_prostitution_sample["X"]

# %%
fig, axes = plt.subplots(2, 2, figsize=(15,15), sharex=True)

sns.distplot(ax = axes[0,0], a=x_veh, kde=True, bins=50, kde_kws=dict(bw=0.02, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
sns.scatterplot(ax = axes[0,0], x=sample_veh_x, y=20)
axes[0,0].set_title("Histogram of vehicle theft by latitude, bw=0.02")

sns.distplot(ax = axes[0,1], a=x_pro, kde=True, bins=50, kde_kws=dict(bw=0.02, color="red"), hist_kws=dict(edgecolor="k", linewidth=1))
sns.scatterplot(ax = axes[0,1], x=sample_pro_x, y=100)
axes[0,1].set_title("Histogram of vehicle theft by latitude, bw=0.02")

sns.distplot(ax = axes[1,0], a=x_veh, kde=True, color="white", bins=50, kde_kws=dict(bw=0.02, color="red"))
sns.scatterplot(ax = axes[1,0], x=sample_veh_x, y=20)
axes[1,0].set_title("Histogram of vehicle theft by latitude, bw=0.02")

sns.distplot(ax = axes[1,1], a=x_pro, kde=True, color="white", bins=50, kde_kws=dict(bw=0.02, color="red"))
sns.scatterplot(ax = axes[1,1], x=sample_pro_x, y=20)
axes[1,1].set_title("Histogram of vehicle theft by latitude, bw=0.02")
# Out:
# Text(0.5, 1.0, 'Histogram of vehicle theft by latitude, bw=0.02')

# %% [markdown]
# *From the above illustrations, it is shown that just having the KDE plot for, for instance vehicle theft gives a wrong image of the data. Generally it is not the worst, but as the sampling is random, this might change from every time the code is run*

# %% [markdown]
# ***Create a probability plot from the assaults data from part-3 exercise-1***

# %%
from scipy import stats

# %%
ax = plt.figure(figsize=(10,10))
x = df_assaults["X"]
res = stats.probplot(x, plot=plt)
plt.ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %% [markdown]
# **Comments on above result:**
#
# *It does not completely follow a gaussian distribution, however it could be discussed if it follows it enough. This is a general way of estimating the distribution, which could be done even better with the confidence interval plotted - which I did not manage to figure out how to do ;)*

# %% [markdown]
# ***We now want show the fluctutations of the crimes happening, over the day***

# %% [markdown]
# *We first define our focuscrimes*

# %%
focuscrimes = ['WEAPON LAWS',
               'PROSTITUTION',
               'DRIVING UNDER THE INFLUENCE',
               'ROBBERY',
               'BURGLARY',
               'ASSAULT',
               'DRUNKENNESS',
               'DRUG/NARCOTIC',
               'TRESPASS',
               'LARCENY/THEFT',
               'VANDALISM',
               'VEHICLE THEFT',
               'STOLEN PROPERTY',
               'DISORDERLY CONDUCT']

# %% [markdown]
# *We start by adding the crimes up in intervals pr. day*

# %%
policing_dataframe["Date"] = policing_dataframe["Date_Time"].dt.date

# %%
counts_pr_category = policing_dataframe.groupby(by=["Category", "Date"]).size().reset_index(name="counts")

# %%
data = []
for crime in focuscrimes:
    temp = counts_pr_category.loc[counts_pr_category['Category'] == crime].reset_index(drop=True)
    data.append(temp['counts'])

# %%
fig1, ax1 = plt.subplots(figsize=(15,15))
ax1.set_title('Crimes commited pr. day for each of the focus crimes')
ax1.boxplot(data, meanline=True)
ax1.set_xticklabels(focuscrimes, rotation="vertical")
ax1.set_ylabel("crimes pr. day")
plt.show()

# %% [markdown]
# ***Comment on the above plot***
#
# *From the plot above it becomes clear that the median is not always the middle of the dataset. It also shows that a mean value can be a poor way to represent the dataset in some cases. Like with the `LARCENY/THEFT` box. It's obvious that the mean is a displaced value that makes you assume that there is no variation*

# %% [markdown]
# ***We now want to create a boxplot that shows the crimes distributed over the day***

# %% [markdown]
# *We start of by creating a function that can calculate and add the time since midnight*

# %%
def seconds_since_midnight(dataframe):
    from_time = pd.Timestamp("00:00:00")
    to_time = dataframe.time()
    return to_time.hour * 3600 + to_time.minute * 60

# %% [markdown]
# *We apply above function*

# %%
policing_dataframe["Time since midnight"] = policing_dataframe.Date_Time.apply(seconds_since_midnight)

# %% [markdown]
# *We filter by the time of day and category*

# %%
time_of_day_pr_category = policing_dataframe.groupby(by=["Category", "Time since midnight"]).size().reset_index(name="counts")

# %% [markdown]
# *We create the datasets seperately*

# %%
data = []
for crime in focuscrimes:
    temp = time_of_day_pr_category.loc[time_of_day_pr_category['Category'] == crime].reset_index(drop=True)
    data.append(temp['Time since midnight'])

# %% [markdown]
# *We create the y-axis labels*

# %%
seconds_pr_hour = [3600*i for i in range(0,25)]

# %% [markdown]
# *We now plot the data in a box-plot*

# %%
fig1, ax1 = plt.subplots(figsize=(15,15))
ax1.set_title('Crimes commited in given time pr. day for each of the focus crimes')
ax1.boxplot(data, meanline=True)
ax1.set_xticklabels(focuscrimes, rotation="vertical")
ax1.set_yticks(seconds_pr_hour)
ax1.set_yticklabels(range(0,25))
ax1.set_ylabel("Time of day when crime was commited")
plt.show()

# %% [markdown]
# ***Comment on the above graph***
#
# *It's obvious to see from the above graph that the crimes do happen quite distributed over the day - but mostly from 06:00 - 18:00, which to be frank, I find weird. It would be nice to see an example plot to see if this is correct. It also seems that this might be misrepresentative, since the weekend and weekdays are mixed together*
